# %%
# Binary Columns
application_df["Gender"].replace(['F','M'], [1,0], inplace=True)
application_df["Own Car"].replace(['Y','N'], [1,0], inplace=True)
application_df["Own Realty"].replace(['Y','N'], [1,0], inplace=True)
application_df["Approval Status"].replace(['Approved','Rejected'], [1,0], inplace=True)

# %%
Rejection ={
  np.nan:0, 
  'Mistakes in the application form':1,
  'Owning multiple cards':2,
  'Occupation':3,
  'Low Income':4,
  'Location verification':5,
  'Bad Credit Score':6
 }
Credit_Category = {
    'Fair':0, 
    'Good':1, 
    'Moderate':2, 
    'Low':3, 
    'Poor':4, 
    'Excellent':5
}


application_df["Reason for Rejection"].replace(Rejection, inplace=True)
application_df["Credit Score Category"].replace(Credit_Category, inplace=True)

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
application_df['Income Type']= label_encoder.fit_transform(application_df['Income Type'])
application_df['Education']= label_encoder.fit_transform(application_df['Education'])
application_df['Family Status']= label_encoder.fit_transform(application_df['Family Status'])
application_df['Housing Type']= label_encoder.fit_transform(application_df['Housing Type'])
application_df['Occupation Type']= label_encoder.fit_transform(application_df['Occupation Type'])

# %%
application_df['Annual Income']=application_df['Annual Income'].astype('int64')
application_df['Occupation Type']=application_df['Occupation Type'].astype('int64')

# %%
application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     438557 non-null  int64
#  1   Gender                 438557 non-null  int64
#  2   Own Car                438557 non-null  int64
#  3   Own Realty             438557 non-null  int64
#  4   Children Count         438557 non-null  int64
#  5   Annual Income          438557 non-null  int64
#  6   Income Type            438557 non-null  int32
#  7   Education              438557 non-null  int32
#  8   Family Status          438557 non-null  int32
#  9   Housing Type           438557 non-null  int32
#  10  Flag Mobile            438557 non-null  int64
#  11  Flag Work Phone        438557 non-null  int64
#  12  Flag Phone             438557 non-null  int64
#  13  Flag Email             438557 non-null  int64
# ...

# %%
application_df.head()
# Out:
#         ID  Gender  Own Car  Own Realty  Children Count  Annual Income  \
# 0  5008804       0        1           1               0         427500
# 1  5008805       0        1           1               0         427500
# 2  5008806       0        1           1               0         112500
# 3  5008808       1        0           1               0         270000
# 4  5008809       1        0           1               0         270000
#
#    Income Type  Education  Family Status  Housing Type  ...  Flag Email  \
# 0            4          1              0             4  ...           0
# 1            4          1              0             4  ...           0
# 2            4          4              1             1  ...           0
# 3            0          4              3             1  ...           1
# 4            0          4              3             1  ...           1
#
#    Occupation Type  Family Members Count  Approval Status  \
# ...
